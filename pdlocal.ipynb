# %%
import pandas as pd

# %%
# Read the data
data = pd.read_csv('E:\OneDrive - Odemi Lab\Escritorio\Productos-2022-Clic-en-el-grafico-para-seleccionar.csv')

# %%
# Print the first five rows of the data
data.head()
# Out:
#    Chapter 4 Digit ID              Chapter 4 Digit  HS2 4 Digit ID  \
# 0                   2  Productos del Reino Vegetal             207
# 1                   2  Productos del Reino Vegetal             207
# 2                   2  Productos del Reino Vegetal             207
# 3                   2  Productos del Reino Vegetal             207
# 4                   2  Productos del Reino Vegetal             207
#
#                                          HS2 4 Digit  HS4 4 Digit ID  \
# 0  Hortalizas, Plantas, Raíces y Tubérculos Alime...           20702
# 1  Hortalizas, Plantas, Raíces y Tubérculos Alime...           20703
# 2  Hortalizas, Plantas, Raíces y Tubérculos Alime...           20704
# 3  Hortalizas, Plantas, Raíces y Tubérculos Alime...           20705
# 4  Hortalizas, Plantas, Raíces y Tubérculos Alime...           20706
#
#                                          HS4 4 Digit  Trade Value     Share
# ...

# %%
# Print the last five rows of the data
data.tail()
# Out:
#      Chapter 4 Digit ID      Chapter 4 Digit  HS2 4 Digit ID  \
# 364                  20              Diverso            2096
# 365                  20              Diverso            2096
# 366                  20              Diverso            2096
# 367                  20              Diverso            2096
# 368                  21  Arte y Antigüedades            2197
#
#                                     HS2 4 Digit  HS4 4 Digit ID  \
# 364                       Manufacturas Diversas          209606
# 365                       Manufacturas Diversas          209607
# 366                       Manufacturas Diversas          209610
# 367                       Manufacturas Diversas          209612
# 368  Objetos de Arte o Colección y Antigüedades          219701
#
#                                            HS4 4 Digit  Trade Value     Share
# 364  Botones y Botones de Presión; Formas para Boto...        18781  0.000115
# ...

# %%
# Print the number of rows and columns of the data
data.shape
# Out:
# (369, 8)

# %%
# Print the column names of the data
data.columns
# Out:
# Index(['Chapter 4 Digit ID', 'Chapter 4 Digit', 'HS2 4 Digit ID',
#        'HS2 4 Digit', 'HS4 4 Digit ID', 'HS4 4 Digit', 'Trade Value', 'Share'],
#       dtype='object')

# %%
# Print the data types of the data
data.dtypes
# Out:
# Chapter 4 Digit ID      int64
# Chapter 4 Digit        object
# HS2 4 Digit ID          int64
# HS2 4 Digit            object
# HS4 4 Digit ID          int64
# HS4 4 Digit            object
# Trade Value             int64
# Share                 float64
# dtype: object

# %%
# Print the summary statistics of the data
data.describe()
# Out:
#        Chapter 4 Digit ID  HS2 4 Digit ID  HS4 4 Digit ID   Trade Value  \
# count          369.000000      369.000000      369.000000  3.690000e+02
# mean            12.772358     1343.360434   134353.111111  4.427558e+07
# std              4.532155      475.625438    47568.239556  1.984201e+08
# min              2.000000      207.000000    20702.000000  1.410000e+02
# 25%             10.000000     1048.000000   104808.000000  6.580500e+04
# 50%             15.000000     1573.000000   157320.000000  5.810960e+05
# 75%             16.000000     1684.000000   168477.000000  1.006524e+07
# max             21.000000     2197.000000   219701.000000  2.922416e+09
#
#               Share
# count  3.690000e+02
# mean   2.710027e-01
# std    1.214493e+00
# min    8.630351e-07
# 25%    4.027803e-04
# 50%    3.556782e-03
# 75%    6.160746e-02
# max    1.788757e+01

# %%
# Print the summary statistics of the data
data.describe(include='all')
# Out:
#         Chapter 4 Digit ID Chapter 4 Digit  HS2 4 Digit ID  \
# count           369.000000             369      369.000000
# unique                 NaN              18             NaN
# top                    NaN        Máquinas             NaN
# freq                   NaN              93             NaN
# mean             12.772358             NaN     1343.360434
# std               4.532155             NaN      475.625438
# min               2.000000             NaN      207.000000
# 25%              10.000000             NaN     1048.000000
# 50%              15.000000             NaN     1573.000000
# 75%              16.000000             NaN     1684.000000
# max              21.000000             NaN     2197.000000
#
#                                            HS2 4 Digit  HS4 4 Digit ID  \
# count                                              369      369.000000
# unique                                              60             NaN
# ...

# %%
# Print the unique values of the data
data['Chapter 4 Digit'].unique() # Product is the name of the column
# Out:
# array(['Productos del Reino Vegetal', 'Los Productos Alimenticios',
#        'Productos Minerales', 'Productos Químicos', 'Plásticos y Cauchos',
#        'Pieles de Animales', 'Productos de Madera', 'Artículos de Papel',
#        'Textiles', 'Calzado, y Sombreros', 'Piedra y Cristal',
#        'Metales Preciosos', 'Rieles', 'Máquinas', 'Transporte',
#        'Instrumentos', 'Diverso', 'Arte y Antigüedades'], dtype=object)

# %%
# Print the unique values of the data
data['Chapter 4 Digit'].value_counts() # Product is the name of the column
# Out:
# Máquinas                       93
# Rieles                         76
# Textiles                       36
# Plásticos y Cauchos            32
# Productos Químicos             24
# Instrumentos                   21
# Artículos de Papel             18
# Productos del Reino Vegetal    14
# Diverso                        14
# Piedra y Cristal               14
# Productos de Madera             8
# Transporte                      5
# Los Productos Alimenticios      5
# Productos Minerales             3
# Calzado, y Sombreros            2
# Metales Preciosos               2
# Pieles de Animales              1
# Arte y Antigüedades             1
# Name: Chapter 4 Digit, dtype: int64

# %%
# Print the unique values of the data
data['Chapter 4 Digit'].value_counts(normalize=True) *100 # Product is the name of the column
# Out:
# Máquinas                       25.203252
# Rieles                         20.596206
# Textiles                        9.756098
# Plásticos y Cauchos             8.672087
# Productos Químicos              6.504065
# Instrumentos                    5.691057
# Artículos de Papel              4.878049
# Productos del Reino Vegetal     3.794038
# Diverso                         3.794038
# Piedra y Cristal                3.794038
# Productos de Madera             2.168022
# Transporte                      1.355014
# Los Productos Alimenticios      1.355014
# Productos Minerales             0.813008
# Calzado, y Sombreros            0.542005
# Metales Preciosos               0.542005
# Pieles de Animales              0.271003
# Arte y Antigüedades             0.271003
# Name: Chapter 4 Digit, dtype: float64

# %%
# import the library
import matplotlib.pyplot as plt

# %%
# Plot the histogram
data['Chapter 4 Digit'].value_counts().plot(kind='bar') # Product is the name of the column
# Out:
# <AxesSubplot:>

# %%
# Plot the histogram
data['Chapter 4 Digit'].value_counts().plot(kind='bar', rot=0) # rot=0 is to rotate the x-axis labels
# Out:
# <AxesSubplot:>

# %%
# Plot the histogram
data['Chapter 4 Digit'].value_counts().plot(kind='bar', rot=0, figsize=(10,5)) # figsize is to change the size of the plot
# Out:
# <AxesSubplot:>

# %%
# Plot the histogram
data['Chapter 4 Digit'].value_counts().plot(kind='bar', rot=0, figsize=(10,5), color='red') # color is to change the color of the bars
# Out:
# <AxesSubplot:>

# %%
# Plot the histogram
data['Chapter 4 Digit'].value_counts().plot(kind='bar', rot=0, figsize=(10,5), color='red', fontsize=15) # fontsize is to change the size of the x-axis labels
# Out:
# <AxesSubplot:>

# %%
# Plot the histogram
data['Chapter 4 Digit'].value_counts().plot(kind='bar', rot=0, figsize=(10,5), color='red', fontsize=15, title='Products') # title is to add a title to the plot
# Out:
# <AxesSubplot:title={'center':'Products'}>

# %%
# Plot the histogram
data['Chapter 4 Digit'].value_counts().plot(kind='bar', rot=0, figsize=(10,5), color='red', fontsize=15, title='Products', ylabel='Frequency') # ylabel is to add a label to the y-axis
# Out:
# <AxesSubplot:title={'center':'Products'}, ylabel='Frequency'>

# %%
# Plot the histogram
data['Chapter 4 Digit'].value_counts().plot(kind='bar', rot=0, figsize=(10,5), color='red', fontsize=15, title='Sales of Products', ylabel='Frequency', xlabel='Products') # xlabel is to add a label to the x-axi
# Out:
# <AxesSubplot:title={'center':'Sales of Products'}, xlabel='Products', ylabel='Frequency'>

# %%
# Plot the histogram
data['Chapter 4 Digit'].value_counts().plot(kind='bar', rot=0, figsize=(10,5), color='red', fontsize=15, title='Sales of Products', ylabel='Frequency', xlabel='Products', grid=True) # grid is to add a grid to the plot
# Out:
# <AxesSubplot:title={'center':'Sales of Products'}, xlabel='Products', ylabel='Frequency'>

# %%
# Plot the histogram
data['Chapter 4 Digit'].value_counts().plot(kind='bar', rot=0, figsize=(10,5), color='red', fontsize=15, title='Sales of Products', ylabel='Frequency', xlabel='Products', grid=True, legend=False) # legend is to remove the legend
# Out:
# <AxesSubplot:title={'center':'Sales of Products'}, xlabel='Products', ylabel='Frequency'>

# %%
# Plot the histogram
data['Chapter 4 Digit'].value_counts().plot(kind='bar', rot=0, figsize=(10,5), color='red', fontsize=15, title='Sales of Products', ylabel='Frequency', xlabel='Products', grid=True, legend=False, ylim=(0,100)) # ylim is to change the range of the y-axis
# Out:
# <AxesSubplot:title={'center':'Sales of Products'}, xlabel='Products', ylabel='Frequency'>

# %%
# Plot the histogram
data['Chapter 4 Digit'].value_counts().plot(kind='bar', rot=0, figsize=(10,5), color='red', fontsize=15, title='Sales of Products', ylabel='Frequency', xlabel='Products', grid=True, legend=False, ylim=(0,100), xlim=(0,10)) # xlim is to change the range of the x-axis
# Out:
# <AxesSubplot:title={'center':'Sales of Products'}, xlabel='Products', ylabel='Frequency'>

# %%
# Plot the histogram The first 10 products
data['Chapter 4 Digit'].value_counts().head(10).plot(kind='bar', figsize=(10,5), color='red', fontsize=15, title='Sales of Products', ylabel='Frequency', xlabel='Products', grid=True, legend=False, ylim=(0,100), xlim=(0,10)) # xlim is to change the range of the x-axis
# Out:
# <AxesSubplot:title={'center':'Sales of Products'}, xlabel='Products', ylabel='Frequency'>

# %%
# types of plots in matplotlib
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
# make the plot bigger and change the style of the plot to ggplot (this is a style of the plot) 
plt.style.use('ggplot')
data['Chapter 4 Digit'].value_counts().head(10).plot(kind='bar', figsize=(10,5), color='red', fontsize=15, title='Sales of Products', ylabel='Frequency', xlabel='Products', grid=True, legend=False, ylim=(0,100), xlim=(0,10)) # xlim is to change the range of the x-axis
# Out:
# <AxesSubplot:title={'center':'Sales of Products'}, xlabel='Products', ylabel='Frequency'>

# %%
# names of the columns
data.columns
# Out:
# Index(['Chapter 4 Digit ID', 'Chapter 4 Digit', 'HS2 4 Digit ID',
#        'HS2 4 Digit', 'HS4 4 Digit ID', 'HS4 4 Digit', 'Trade Value', 'Share'],
#       dtype='object')

# %%
# show the first five rows of the data
data.head()
# Out:
#    Chapter 4 Digit ID              Chapter 4 Digit  HS2 4 Digit ID  \
# 0                   2  Productos del Reino Vegetal             207
# 1                   2  Productos del Reino Vegetal             207
# 2                   2  Productos del Reino Vegetal             207
# 3                   2  Productos del Reino Vegetal             207
# 4                   2  Productos del Reino Vegetal             207
#
#                                          HS2 4 Digit  HS4 4 Digit ID  \
# 0  Hortalizas, Plantas, Raíces y Tubérculos Alime...           20702
# 1  Hortalizas, Plantas, Raíces y Tubérculos Alime...           20703
# 2  Hortalizas, Plantas, Raíces y Tubérculos Alime...           20704
# 3  Hortalizas, Plantas, Raíces y Tubérculos Alime...           20705
# 4  Hortalizas, Plantas, Raíces y Tubérculos Alime...           20706
#
#                                          HS4 4 Digit  Trade Value     Share
# ...

# %%
#import the library
import seaborn as sns

# %%
# import the library
import numpy as np

# %%
# delete the rows with missing values
data = data.dropna()

# %%
# make a $ sign to the price column
data['Trade Value'] = data['Trade Value'].apply(lambda x: '$' + str(x))

# %%
# show the first five rows of the data
data.head()
# Out:
#    Chapter 4 Digit ID              Chapter 4 Digit  HS2 4 Digit ID  \
# 0                   2  Productos del Reino Vegetal             207
# 1                   2  Productos del Reino Vegetal             207
# 2                   2  Productos del Reino Vegetal             207
# 3                   2  Productos del Reino Vegetal             207
# 4                   2  Productos del Reino Vegetal             207
#
#                                          HS2 4 Digit  HS4 4 Digit ID  \
# 0  Hortalizas, Plantas, Raíces y Tubérculos Alime...           20702
# 1  Hortalizas, Plantas, Raíces y Tubérculos Alime...           20703
# 2  Hortalizas, Plantas, Raíces y Tubérculos Alime...           20704
# 3  Hortalizas, Plantas, Raíces y Tubérculos Alime...           20705
# 4  Hortalizas, Plantas, Raíces y Tubérculos Alime...           20706
#
#                                          HS4 4 Digit  Trade Value  Share
# 0                     Tomates Frescos o Refrigerados     21255066   0.13
# ...
