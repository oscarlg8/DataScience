# %%
import pandas as pd

# %%
# Read the data salario
df = pd.read_csv('E:\\OneDrive - Odemi Lab\\Odemilab\\DATA SCIENCE\\DATA REYNOSA 2022\\Distribucion-fuerza-laboral-Total-por-ocupaciones-en-TamaulipasColoreado-por-salario-promedio-mensual-en-cuarto-trimestre-de-2022.csv')

# %%
df.head()
# Out:
#    Category ID                          Category  Group ID  \
# 0            1  Funcionarios, Directores y Jefes        11
# 1            1  Funcionarios, Directores y Jefes        11
# 2            1  Funcionarios, Directores y Jefes        11
# 3            1  Funcionarios, Directores y Jefes        11
# 4            1  Funcionarios, Directores y Jefes        12
#
#                                                Group  Subgroup ID  \
# 0  Funcionarios y Altas Autoridades de los Sector...          111
# 1  Funcionarios y Altas Autoridades de los Sector...          112
# 2  Funcionarios y Altas Autoridades de los Sector...          113
# 3  Funcionarios y Altas Autoridades de los Sector...          113
# 4  Directores y Gerentes en Servicios Financieros...          121
#
#                                             Subgroup  Occupation ID  \
# 0  Funcionarios, Legisladores y Autoridades Guber...           1113
# 1                 Presidentes y Directores Generales           1122
# 2  Directores de Organizaciones Políticas, Sindic...           1131
# 3  Directores de Organizaciones Políticas, Sindic...           1135
# 4  Directores y Gerentes en Servicios Financieros...           1211
#
#                                           Occupation  Year  Quarter ID  \
# 0              Presidentes y Autoridades Municipales  2022       20224
# 1  Presidentes y Directores Generales en Instituc...  2022       20224
# 2             Directores de Organizaciones Políticas  2022       20224
# 3  Directores de Organizaciones Civiles y Religiosas  2022       20224
# 4  Directores y Gerentes en Administración, Recur...  2022       20224
#
#    Quarter  Workforce  Monthly Wage  Monthly Wage Growth  \
# 0  2022-Q4        582  35000.000000              1.00000
# 1  2022-Q4        508  61811.023622              1.00000
# 2  2022-Q4         93   8000.000000              1.00000
# 3  2022-Q4        455      0.000000              1.00000
# 4  2022-Q4       1245  10763.052209             -0.53867
#
#    Monthly Wage Growth Value  percentage    lastPeriod
# 0               35000.000000    0.000364      0.000000
# 1               61811.023622    0.000318      0.000000
# 2                8000.000000    0.000058      0.000000
# 3                   0.000000    0.000284      0.000000
# 4              -12567.434312    0.000778  23330.486521

# %%
# create a new column called 'AreaID' with string 'ingenieros' if 'Subgroup' contains a string 'Ing' and 'licenciados' if 'Subgroup' contains a string 'Adm'
df['Area ID'] = df['Subgroup'].apply(lambda x: 7 if 'Ing' in x else 4 if 'Adm' in x else 0)

# %%
df.head()
# Out:
#    Category ID                          Category  Group ID  \
# 0            1  Funcionarios, Directores y Jefes        11
# 1            1  Funcionarios, Directores y Jefes        11
# 2            1  Funcionarios, Directores y Jefes        11
# 3            1  Funcionarios, Directores y Jefes        11
# 4            1  Funcionarios, Directores y Jefes        12
#
#                                                Group  Subgroup ID  \
# 0  Funcionarios y Altas Autoridades de los Sector...          111
# 1  Funcionarios y Altas Autoridades de los Sector...          112
# 2  Funcionarios y Altas Autoridades de los Sector...          113
# 3  Funcionarios y Altas Autoridades de los Sector...          113
# 4  Directores y Gerentes en Servicios Financieros...          121
#
#                                             Subgroup  Occupation ID  \
# 0  Funcionarios, Legisladores y Autoridades Guber...           1113
# 1                 Presidentes y Directores Generales           1122
# 2  Directores de Organizaciones Políticas, Sindic...           1131
# 3  Directores de Organizaciones Políticas, Sindic...           1135
# 4  Directores y Gerentes en Servicios Financieros...           1211
#
#                                           Occupation  Year  Quarter ID  \
# 0              Presidentes y Autoridades Municipales  2022       20224
# 1  Presidentes y Directores Generales en Instituc...  2022       20224
# 2             Directores de Organizaciones Políticas  2022       20224
# 3  Directores de Organizaciones Civiles y Religiosas  2022       20224
# 4  Directores y Gerentes en Administración, Recur...  2022       20224
#
#    Quarter  Workforce  Monthly Wage  Monthly Wage Growth  \
# 0  2022-Q4        582  35000.000000              1.00000
# 1  2022-Q4        508  61811.023622              1.00000
# 2  2022-Q4         93   8000.000000              1.00000
# 3  2022-Q4        455      0.000000              1.00000
# 4  2022-Q4       1245  10763.052209             -0.53867
#
#    Monthly Wage Growth Value  percentage    lastPeriod  Area ID
# 0               35000.000000    0.000364      0.000000        0
# 1               61811.023622    0.000318      0.000000        0
# 2                8000.000000    0.000058      0.000000        0
# 3                   0.000000    0.000284      0.000000        0
# 4              -12567.434312    0.000778  23330.486521        4

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dfmatricula = pd.read_csv('E:\\OneDrive - Odemi Lab\\Odemilab\\DATA SCIENCE\\DATA REYNOSA 2022\\Matriculas-segun-campo-de-formacion-en-Reynosa-Totales-2021.csv')

# %%
dfmatricula.head()
# Out:
#    Area ID       Area  Field ID                                 Field  \
# 0        1  Educación        11  Ciencias de la educación y pedagogía
# 1        1  Educación        11  Ciencias de la educación y pedagogía
# 2        1  Educación        11  Ciencias de la educación y pedagogía
# 3        1  Educación        11  Ciencias de la educación y pedagogía
# 4        1  Educación        11  Ciencias de la educación y pedagogía
#
#    Subfield ID                                           Subfield  Year  \
# 0          110  Planes multidisciplinarios o generales del cam...  2021
# 1          111                      Diseño curricular y pedagogía  2021
# 2          112   Planeación, evaluación e investigación educativa  2021
# 3          113               Orientación e intervención educativa  2021
# 4          115                           Ciencias de la educación  2021
#
#    Students  Students Growth  Students Growth Value  percentage
# 0        80        -0.111111                    -10    0.002495
# 1       351        -0.231947                   -106    0.010949
# 2        68        -0.139241                    -11    0.002121
# 3       297        -0.041935                    -13    0.009264
# 4       484        -0.150877                    -86    0.015097

# %%
#rename AreaID column to AreaIDMatricula
dfmatricula.rename(columns={'AreaID':'AreaID'}, inplace=True)

# %%
df.dtypes
# Out:
# Category ID                    int64
# Category                      object
# Group ID                       int64
# Group                         object
# Subgroup ID                    int64
# Subgroup                      object
# Occupation ID                  int64
# Occupation                    object
# Year                           int64
# Quarter ID                     int64
# Quarter                       object
# Workforce                      int64
# Monthly Wage                 float64
# Monthly Wage Growth          float64
# Monthly Wage Growth Value    float64
# percentage                   float64
# lastPeriod                   float64
# Area ID                        int64
# dtype: object

# %%
dfmatricula.dtypes
# Out:
# Area ID                    int64
# Area                      object
# Field ID                   int64
# Field                     object
# Subfield ID                int64
# Subfield                  object
# Year                       int64
# Students                   int64
# Students Growth          float64
# Students Growth Value      int64
# percentage               float64
# dtype: object

# %%
# merge a dataframe df and dfmatricula on 'AreaID' column
df = pd.merge(df, dfmatricula, on='Area ID')

# %%
df.head(3)
# Out:
#    Category ID                          Category  Group ID  \
# 0            1  Funcionarios, Directores y Jefes        12
# 1            1  Funcionarios, Directores y Jefes        12
# 2            1  Funcionarios, Directores y Jefes        12
#
#                                                Group  Subgroup ID  \
# 0  Directores y Gerentes en Servicios Financieros...          121
# 1  Directores y Gerentes en Servicios Financieros...          121
# 2  Directores y Gerentes en Servicios Financieros...          121
#
#                                             Subgroup  Occupation ID  \
# 0  Directores y Gerentes en Servicios Financieros...           1211
# 1  Directores y Gerentes en Servicios Financieros...           1211
# 2  Directores y Gerentes en Servicios Financieros...           1211
#
#                                           Occupation  Year_x  Quarter ID  ...  \
# 0  Directores y Gerentes en Administración, Recur...    2022       20224  ...
# 1  Directores y Gerentes en Administración, Recur...    2022       20224  ...
# 2  Directores y Gerentes en Administración, Recur...    2022       20224  ...
#
#                         Area  Field ID                    Field  Subfield ID  \
# 0  Administración y negocios        41  Negocios y contabilidad          411
# 1  Administración y negocios        41  Negocios y contabilidad          412
# 2  Administración y negocios        41  Negocios y contabilidad          413
#
#                      Subfield  Year_y  Students  Students Growth  \
# 0         Negocios y comercio    2021      1591        -0.043870
# 1  Mercadotecnia y publicidad    2021      1100         0.353014
# 2   Finanzas, banca y seguros    2021        19        -0.406250
#
#   Students Growth Value  percentage_y
# 0                   -73      0.049627
# 1                   287      0.034312
# 2                   -13      0.000593
#
# [3 rows x 28 columns]

# %%
df.dtypes
# Out:
# Category ID                    int64
# Category                      object
# Group ID                       int64
# Group                         object
# Subgroup ID                    int64
# Subgroup                      object
# Occupation ID                  int64
# Occupation                    object
# Year_x                         int64
# Quarter ID                     int64
# Quarter                       object
# Workforce                      int64
# Monthly Wage                 float64
# Monthly Wage Growth          float64
# Monthly Wage Growth Value    float64
# percentage_x                 float64
# lastPeriod                   float64
# Area ID                        int64
# Area                          object
# Field ID                       int64
# Field                         object
# Subfield ID                    int64
# Subfield                      object
# Year_y                         int64
# Students                       int64
# Students Growth              float64
# Students Growth Value          int64
# percentage_y                 float64
# dtype: object

# %%
dfworkers = pd.read_csv('E:\\OneDrive - Odemi Lab\\Odemilab\\DATA SCIENCE\\DATA REYNOSA 2022\\Distribucion-fuerza-laboral-Total-por-ocupaciones-en-Tamaulipascuarto-trimestre-de-2022.csv')

# %%
dfworkers.columns
# Out:
# Index(['Category ID', 'Category', 'Group ID', 'Group', 'Subgroup ID',
#        'Subgroup', 'Occupation ID', 'Occupation', 'Year', 'Quarter ID',
#        'Quarter', 'Workforce', 'Workforce Growth', 'Workforce Growth Value',
#        'percentage', 'lastPeriod'],
#       dtype='object')

# %%
# merge a dataframe df and dfworkers on 'Occupation ID' column
df = pd.merge(df, dfworkers, on='Occupation ID')

# %%
df.dtypes
# Out:
# Category ID_x                  int64
# Category_x                    object
# Group ID_x                     int64
# Group_x                       object
# Subgroup ID_x                  int64
# Subgroup_x                    object
# Occupation ID                  int64
# Occupation_x                  object
# Year_x                         int64
# Quarter ID_x                   int64
# Quarter_x                     object
# Workforce_x                    int64
# Monthly Wage                 float64
# Monthly Wage Growth          float64
# Monthly Wage Growth Value    float64
# percentage_x                 float64
# lastPeriod_x                 float64
# Area ID                        int64
# Area                          object
# Field ID                       int64
# Field                         object
# Subfield ID                    int64
# Subfield                      object
# Year_y                         int64
# Students                       int64
# Students Growth              float64
# Students Growth Value          int64
# percentage_y                 float64
# Category ID_y                  int64
# Category_y                    object
# Group ID_y                     int64
# Group_y                       object
# Subgroup ID_y                  int64
# Subgroup_y                    object
# Occupation_y                  object
# Year                           int64
# Quarter ID_y                   int64
# Quarter_y                     object
# Workforce_y                    int64
# Workforce Growth             float64
# Workforce Growth Value         int64
# percentage                   float64
# lastPeriod_y                   int64
# dtype: object

# %%
# create a 20x50 scatter plot of 'Workforce Growth Value' and 'Monthly Wage Growth Value' with 'licenciados' and 'ingenieros' colors with regression line
sns.lmplot(x='Workforce Growth Value', y='Monthly Wage Growth Value', data=df, hue='Area', fit_reg=True, height=10, aspect=2)
